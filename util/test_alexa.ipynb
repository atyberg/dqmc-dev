# %% [markdown]
# ## File for testing Alexa's honeycomb implementation

# %% [markdown]
# First test bond_params function.

# %%
from gen_1band_unified_hub_alexa import bond_params
import numpy as np

# Test for square lattice
geometry = "square"
Nx, Ny = 4, 4
tp = 0.0  # or -0.3 for next-nearest neighbor
tpp = 0.0
trans_sym = 1  # or 0

(bps, num_b, num_b_accum), map_b, degen_b, bonds = bond_params(
    geometry, Nx, Ny, tp, tpp, trans_sym
)

# Print outputs
print(f"Bonds per site: {bps}")
print(f"Total bonds: {num_b}")
print(f"Accumulated bonds: {num_b_accum}")
print(f"\nmap_b shape: {map_b.shape}")
print(f"map_b (first 20): {map_b[:20]}")
print(f"\ndegen_b shape: {degen_b.shape}")
print(f"degen_b: {degen_b}")
print(f"\nbonds shape: {bonds.shape}")
print(f"First few bonds:\n{bonds[:, :8]}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from gen_1band_unified_hub_alexa import bond_params
#       2 import numpy as np
#       4 # Test for square lattice
#
# File ~/Documents/Stanford/Devereaux_Research/group_DQMC_rename/dqmc-dev/util/gen_1band_unified_hub_alexa.py:17
#      14 np.seterr(over="ignore")
#      15 np.set_printoptions(precision=3)
# ---> 17 import git  # relies on gitpython module
#      19 path = os.path.dirname(os.path.abspath(__file__))
#      20 repo = git.Repo(path, search_parent_directories=True)
#
# ModuleNotFoundError: No module named 'git'
